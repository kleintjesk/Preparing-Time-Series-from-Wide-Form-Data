# %% [markdown]
# # Preparing Time Series from Wide-From Data
# Kailin Kleintjes

# %% [markdown]
# # Tasks
# Zillow House Value Index (ZHVI) https://www.zillow.com/research/data/
#
# Specifically,using the Home Value data set for:
#
# - Data Type = "ZHVI All Homes (SFR+Condo/Coop) - Time Series Smoothed - Seasonally Adjusted"
# - Geography = "City"
# We have already downloaded the file for you and uploaded it to Google Drive.
#
# Direct URL (for Pandas): https://docs.google.com/spreadsheets/d/e/2PACX-1vQN3Ksa9szQuO4G1-msXWAp17KtVHQCBnuEieu_auu1wSiBf3-krHusIx5VBMkihxj-KZLBosDIGEyR/pub?output=csv

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import os
import matplotlib.ticker as mticks
import matplotlib.dates as mdates

df = pd.read_csv('Data/City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
# 4          San Antonio-New Braunfels, TX        Bexar County    114794.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# ...

# %%
four = df.loc[0:3]
four
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# 2    109079.0  ...    245783.0    248718.0    252080.0    256435.0
# ...

# %%
#Melt the data
melted = pd.melt(four.drop(columns=['RegionID','SizeRank']),
                 id_vars=['RegionName', 'RegionType', 'StateName',
                               'State', 'Metro', 'CountyName'], 
                 value_name="HomeValue",var_name="Date")
melted
# Out:
#        RegionName RegionType StateName State  \
# 0        New York       city        NY    NY
# 1     Los Angeles       city        CA    CA
# 2         Houston       city        TX    TX
# 3         Chicago       city        IL    IL
# 4        New York       city        NY    NY
# ...           ...        ...       ...   ...
# 1087      Chicago       city        IL    IL
# 1088     New York       city        NY    NY
# 1089  Los Angeles       city        CA    CA
# 1090      Houston       city        TX    TX
# 1091      Chicago       city        IL    IL
#
#                                       Metro          CountyName        Date  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County  2000-01-31
# 1        Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  2000-01-31
# 2      Houston-The Woodlands-Sugar Land, TX       Harris County  2000-01-31
# 3        Chicago-Naperville-Elgin, IL-IN-WI         Cook County  2000-01-31
# ...

# %%
#change date to datetime data type
melted['Date'] = pd.to_datetime(melted['Date'])
melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionName  1092 non-null   object
#  1   RegionType  1092 non-null   object
#  2   StateName   1092 non-null   object
#  3   State       1092 non-null   object
#  4   Metro       1092 non-null   object
#  5   CountyName  1092 non-null   object
#  6   Date        1092 non-null   datetime64[ns]
#  7   HomeValue   1087 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 68.4+ KB

# %%
#set the date as the index
melted = melted.set_index("Date")
melted
# Out:
#              RegionName RegionType StateName State  \
# Date
# 2000-01-31     New York       city        NY    NY
# 2000-01-31  Los Angeles       city        CA    CA
# 2000-01-31      Houston       city        TX    TX
# 2000-01-31      Chicago       city        IL    IL
# 2000-02-29     New York       city        NY    NY
# ...                 ...        ...       ...   ...
# 2022-08-31      Chicago       city        IL    IL
# 2022-09-30     New York       city        NY    NY
# 2022-09-30  Los Angeles       city        CA    CA
# 2022-09-30      Houston       city        TX    TX
# 2022-09-30      Chicago       city        IL    IL
#
#                                             Metro          CountyName  \
# Date
# 2000-01-31  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 2000-01-31     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 2000-01-31   Houston-The Woodlands-Sugar Land, TX       Harris County
# ...

# %%
#Find null values
melted.isna().sum()
# Out:
# RegionName    0
# RegionType    0
# StateName     0
# State         0
# Metro         0
# CountyName    0
# HomeValue     5
# dtype: int64

# %%
#Impute null values
melted = melted.interpolate()
melted.isna().sum()
# Out:
# RegionName    0
# RegionType    0
# StateName     0
# State         0
# Metro         0
# CountyName    0
# HomeValue     0
# dtype: int64

# %%
#resample by creating a multi index with the different cities using a monthly frequency
df_ts = melted.groupby('RegionName').resample("M").sum()
df_ts
# Out:
# C:\Users\klein\AppData\Local\Temp\ipykernel_18352\2702474838.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_ts = melted.groupby('RegionName').resample("M").sum()
# C:\Users\klein\AppData\Local\Temp\ipykernel_18352\2702474838.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_ts = melted.groupby('RegionName').resample("M").sum()
# ...

# %% [markdown]
# # Part 2

# %% [markdown]
# # 1) Which City had the highest Typical Home Value at the end of 2008? Which had the least?

# %%
#define our region names and create a copy of our dataframe
RegionNames = ['Chicago','New York','Houston','Los Angeles']
plot_df = df_ts.loc[RegionNames].copy()
plot_df
# Out:
#                         HomeValue
# RegionName  Date
# Chicago     2000-01-31   166139.0
#             2000-02-29   166536.0
#             2000-03-31   167368.0
#             2000-04-30   168826.0
#             2000-05-31   170499.0
# ...                           ...
# Los Angeles 2022-05-31   990391.0
#             2022-06-30   992337.0
#             2022-07-31   992630.0
#             2022-08-31   978196.0
#             2022-09-30   966595.0
#
# [1092 rows x 1 columns]

# %%
#unstack the multi-index
unstacked = plot_df.unstack(level=0)
unstacked
# Out:
#            HomeValue
# RegionName   Chicago   Houston Los Angeles  New York
# Date
# 2000-01-31  166139.0  109068.0    234181.0  253690.0
# 2000-02-29  166536.0  109079.0    234401.0  255517.0
# 2000-03-31  167368.0  108878.0    235513.0  257207.0
# 2000-04-30  168826.0  108881.0    237589.0  260310.0
# 2000-05-31  170499.0  108834.0    240113.0  263204.0
# ...              ...       ...         ...       ...
# 2022-05-31  312487.0  265558.0    990391.0  768797.0
# 2022-06-30  314663.0  268901.0    992337.0  773944.0
# 2022-07-31  315910.0  271059.0    992630.0  777692.0
# 2022-08-31  315587.0  272400.0    978196.0  779960.0
# 2022-09-30  315429.0  272639.0    966595.0  781622.0
#
# [273 rows x 4 columns]

# %%
#define thousands format
def thousands(x,pos):
    """function for use wth matplotlib FuncFormatter -  formats money in millions"""
    new_x = x/1_000
    return f"{new_x:,.0f}K"
fmt_thous = mticks.FuncFormatter(thousands)

# %%
ax=unstacked['HomeValue'].plot(title='Home Values by Major City', ylabel='Home Value in Dollars')
ax.yaxis.set_major_formatter(fmt_thous)

# %%
#create a copy dataframe of just the year 2008 for plotting
oneyear = unstacked.loc['2008'].copy()
oneyear
# Out:
#            HomeValue
# RegionName   Chicago   Houston Los Angeles  New York
# Date
# 2008-01-31  300207.0  138208.0    603029.0  546538.0
# 2008-02-29  296063.0  137512.0    596635.0  546098.0
# 2008-03-31  339330.0  136795.0    586065.0  544562.0
# 2008-04-30  337156.5  136628.0    571226.0  541865.0
# 2008-05-31  293467.0  136228.0    554589.0  537685.0
# 2008-06-30  288495.0  135773.0    539622.0  533810.0
# 2008-07-31  288174.0  135392.0    524220.0  529211.0
# 2008-08-31  283199.0  134770.0    510520.0  525290.0
# 2008-09-30  280695.0  133932.0    500124.0  521347.0
# 2008-10-31  274849.0  133189.0    490979.0  518048.0
# 2008-11-30  271059.0  132247.0    481905.0  514767.0
# 2008-12-31  265306.0  131283.0    469294.0  510309.0

# %%
#create a copy df to find the highest and lowest value
copydf = plot_df.loc[pd.IndexSlice[:,'12/2008'],:].copy()
copydf
# Out:
#                         HomeValue
# RegionName  Date
# Chicago     2008-12-31   265306.0
# New York    2008-12-31   510309.0
# Houston     2008-12-31   131283.0
# Los Angeles 2008-12-31   469294.0

# %%
#find the highest value
maxvalue = copydf.idxmax()
copydf.loc[maxvalue]
# Out:
#                        HomeValue
# RegionName Date
# New York   2008-12-31   510309.0

# %%
#find the lowest value
minvalue = copydf.idxmin()
copydf.loc[minvalue]
# Out:
#                        HomeValue
# RegionName Date
# Houston    2008-12-31   131283.0

# %%
#plot the max and min
fig, ax = plt.subplots(figsize=(12,3))
copydf['HomeValue'].plot(ax=ax,title='Min and Max Home values at the end of 2008',ylabel='Home Values');
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(ax.get_xticklabels(), fontsize='large',fontweight='bold' );
ax.yaxis.set_major_formatter(fmt_thous)
ax.axvline("New York, 2008-12-31",color='red',lw=1, label='New York $510,309')
ax.axvline("Houston, 2008-12-31",color='red',lw=1, label='Houston $131,283')
ax.grid(which='minor',axis='x',ls=":")
ax.grid(which='major',axis='x',color='k')
fig.autofmt_xdate(rotation=90,ha='center')
ax.legend();

# %% [markdown]
# The minimum homevalue for 2008 was 131,283 dollars in Houston.
# The max value was 510,309 dollars in New York.

# %% [markdown]
# # 2) How much did the home values change from November 2008 to December 2008 (in dollars)?

# %%
df_diff = oneyear.diff()
df_diff.loc['2008-12-31']-df_diff.loc['2008-11-30']
# Out:
#            RegionName
# HomeValue  Chicago       -1963.0
#            Houston         -22.0
#            Los Angeles   -3537.0
#            New York      -1177.0
# dtype: float64

# %%
nov_dec = df_diff.loc['2008-11-30':'2008-12-31', 'HomeValue'].copy()
nov_dec.plot();

# %% [markdown]
# It looks like Houston barely had any change, with a difference of 22 dollars. New York had a difference of 1177 dollars and Chicago had a difference of 1963 dollars. Los Angeles had the largest difference with 3537 dollars.
